# %%
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import os
import numpy as np
from PIL import Image 
import PIL

# %%
import PIL.Image


data_dir= r"C:\Users\Arun\Downloads\classification"
x=[]
y=[]

classes=os.listdir(data_dir)
print(classes)
# Out:
# ['cat', 'dog']

# %%
for i,j in enumerate(classes):
    class_path=os.path.join(data_dir,j)
    print(os.listdir(class_path))
  
    for img_name in os.listdir(class_path):

        img_path=os.path.join(class_path,img_name)
        print(img_path)
        try:
            img=Image.open(img_path).convert("RGB")
            img=img.resize((128,128))
            img=np.array(img)
            if img.shape == (128,128,3):
                x.append(img)
                y.append(i)
        except Exception as e:
            print(f"error loading {img_path} : {e}")
# Out:
# ['cat.webp']
# C:\Users\Arun\Downloads\classification\cat\cat.webp
# ['dog.webp']
# C:\Users\Arun\Downloads\classification\dog\dog.webp

# %%
x=np.array(x)/255.0
y=np.array(y)
print(len(x))
print(x.shape)
print(y.shape)
print(y)
# Out:
# 2
# (2, 128, 128, 3)
# (2,)
# [0 1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train.shape,"\n",y_train.shape,"\n",x_test.shape,"\n",y_test.shape)
# Out:
# (1, 128, 128, 3)
#  (1,)
#  (1, 128, 128, 3)
#  (1,)

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[0])
plt.show()
print(y_train[0])
print(classes[y_train[0]])
# Out:
# 0
# cat

# %%
# # for i in range(5):
# #     print(f"in f{y_train[i]} class: {classes[y_train[0]]}")
# print(classes)
# print(len(classes))
# print(np.unique(y_train))
